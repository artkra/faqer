# %%
import nltk
import matplotlib.pyplot as plt
import numpy as np
from copy import copy
nltk.data.path.append('./data')
nltk.download('stopwords', './data/')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to ./data/...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /home/artkra/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from collections import Counter
c = Counter()

# %%
with open('../../data/slack/messages.txt', 'r') as fr:
    with open('../../data/slack/tokens.txt', 'w') as fw:
        for line in fr.readlines():
            if '?' in line:
                tokens = [w.lower() for w in nltk.tokenize.word_tokenize(line) if w.isalpha()]
                tokens = [w for w in tokens if w not in nltk.corpus.stopwords.words('russian')]
                tokens = [w for w in tokens if w not in nltk.corpus.stopwords.words('english')]
                c += Counter(tokens)
                fw.write(','.join(tokens) + '\n')

# %%
X = []
Y = []
WORDS = []
for i, word in enumerate(sorted(c, key=lambda x: c[x], reverse=True)):
    X.append(i)
    WORDS.append(word)
    Y.append(c[word])
plt.plot(X, Y, marker='o')
plt.xlim([0, 20])
plt.show()

# %%
YSHIFTED = copy(Y)
YSHIFTED = YSHIFTED[1::]
YSHIFTED.append(0)

# %%
DIFFS = np.array(Y) - np.array(YSHIFTED)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

torch.manual_seed(1)

# %%
def get_text():
    with open('../../data/slack/messages.txt', 'r') as fr:
        return fr.read()


def tokenize_text(text):
    def to_include(word):
        if any([
            not word.isalpha(),
            word in nltk.corpus.stopwords.words('russian'),
            word in nltk.corpus.stopwords.words('english')
        ]):
            return False
        return True
    tokens = [w.lower() for w in nltk.tokenize.word_tokenize(text) if to_include(w)]
    return tokens


def count_freq(tokens):
    c = Counter(tokens)
    return sorted(c, key=lambda x: c[x])

# %%
TOKENS = tokenize_text(get_text())

# %%
count_freq(TOKENS)
# Out:
# ['award',
#  'spacibo',
#  'живется',
#  'присоединяй',
#  'сравнении',
#  'драстуте',
#  'переключения',
#  'завалил',
#  'аццкий',
#  'требую',
#  'открытия',
#  'returns',
#  'simply',
#  'causes',
#  'теме',
#  'откатываем',
#  'дискомфортно',
#  'стабильную',
#  'известна',
#  'обдумываем',
#  'имеющимися',
#  'ежли',
#  'приходи',
#  'узнаешь',
#  'деталях',
#  'сможешь',
#  'решении',
#  'перебросили',
#  'поможем',
#  'конечные',
#  'выглядеть',
#  'operations',
#  'конкретных',
#  'группа',
#  'даём',
#  'возможен',
#  'подобном',
#  'полной',
#  'переустановкой',
#  'предварительно',
#  'сохраним',
#  'официальной',
#  'поддержки',
#  'оф',
#  'декстопной',
#  'разломают',
#  'установленными',
#  'пушем',
#  'запушились',
#  'напрягают',
#  'перевезли',
#  'реализует',
#  'autodeploy',
#  'выдавало',
#  'серваке',
#  'взаимодействие',
#  'извлечь',
#  'выплюнул',
#  'успевал',
#  'отработать',
#  'замерял',
#  'предназначен',
#  'результатом',
#  'внедрить',
#  'подскажешь',
#  'столь',
#  'разными',
#  'командами',
#  'настраивает',
#  'девопс',
#  'хранилище',
#  'репов',
#  'стриггерить',
#  'deppends',
#  'спасиб',
#  'мучать',
#  'хорошего',
#  'тона',
#  'вначале',
#  'доказывать',
#  'позволю',
#  'вмешаться',
#  'регламентировано',
#  'адекватного',
#  'посему',
#  'разломано',
#  'разламывания',
#  'разломалось',
#  'правильного',
#  'четким',
#  'дедлайном',
#  'костыля',
#  'разламываться',
#  'переделывают',
#  'функциональное',
#  'различные',
#  'прописанные',
#  'дефолтные',
#  'функциональных',
#  'используемый',
#  'кажутся',
#  'таймаутом',
#  'запускаемый',
#  'отрабатывает',
#  'логу',
#  'обрывает',
#  'забить',
#  'таймлайна',
#  'анонсе',
#  'автодеплои',
#  'затраты',
#  'программистов',
#  'резкий',
#  'обучаться',
#  'пойми',
#  'молодцы',
#  'позиции',
#  'прочитал',
#  'выставленные',
#  'подтверждаю',
#  'вскрылся',
#  'четкие',
#  'сроки',
#  'забиваем',
#  'определенное',
#  'входить',
#  'положение',
#  'отделов',
#  'требуем',
#  'срока',
#  'фразу',
#  'ввиду',
#  'поломки',
#  'побежим',
#  'разговоров',
#  'вскрытые',
#  'критичный',
#  'искаться',
#  'дольше',
#  'наезд',
#  'было',
#  'анонсом',
#  'раз',
#  'узнали',
#  'случаи',
#  'репах',
#  'огромный',
#  'бессмысленный',
#  'эффорт',
#  'выданным',
#  'перезагрузилась',
#  'завершив',
#  'произошел',
#  'критический',
#  'сбой',
#  'отключилось',
#  'питание',
#  'категория',
#  'напрягает',
#  'освободится',
#  'починится',
#  'операциях',
#  'скажи',
#  'воспроизвести',
#  'somehow',
#  'related',
#  'switching',
#  'maybe',
#  'чинят',
#  'пытались',
#  'dicrepancy',
#  'stored',
#  'проверили',
#  'нема',
#  'вешался',
#  'pus',
#  'opcode',
#  'noerror',
#  'flags',
#  'qr',
#  'rd',
#  'ra',
#  'ad',
#  'authority',
#  'msg',
#  'rcvd',
#  'unification',
#  'прокатить',
#  'простыня',
#  'получилась',
#  'igmanager',
#  'подправил',
#  'пробуй',
#  'теоретически',
#  'оперативную',
#  'болеть',
#  'работате',
#  'ящикам',
#  'yeah',
#  'converted',
#  'luv',
#  'правды',
#  'скажет',
#  'tcptraceroute',
#  'udptraceroute',
#  'хопе',
#  'требуются',
#  'конретная',
#  'значил',
#  'пользовтель',
#  'научить',
#  'клонировать',
#  'считаю',
#  'сгенерить',
#  'реализация',
#  'боюсь',
#  'далека',
#  'идеала',
#  'спс',
#  'внедряться',
#  'костя',
#  'небольшую',
#  'лешей',
#  'баскаковым',
#  'опсовые',
#  'переписал',
#  'пасиба',
#  'replicate',
#  'ultimately',
#  'loop',
#  'despite',
#  'quite',
#  'whom',
#  'owns',
#  'pals',
#  'uninitialized',
#  'scalar',
#  'chomp',
#  'происходящего',
#  'аномальная',
#  'нагрузка',
#  'плюсую',
#  'проблемам',
#  'решаем',
#  'измененных',
#  'пасаны',
#  'запостите',
#  'отлипает',
#  'подкинул',
#  'скорости',
#  'осторожнее',
#  'товарищ',
#  'майор',
#  'дремлет',
#  'редактор',
#  'отзывчивый',
#  'макросами',
#  'подзабыли',
#  'стартовый',
#  'мож',
#  'su',
#  'системного',
#  'пофикшена',
#  'конфлуенса',
#  'sendmail',
#  'plugins',
#  'мячиков',
#  'mmyachikov',
#  'лежат',
#  'намеренно',
#  'manhattan',
#  'diagnose',
#  'срабатывала',
#  'факторная',
#  'приходил',
#  'решила',
#  'подумала',
#  'свидетельствовать',
#  'неполадках',
#  'перехвата',
#  'верификационных',
#  'оператором',
#  'телеграма',
#  'оператор',
#  'мегафон',
#  'suspiciously',
#  'прописан',
#  'plans',
#  'membership',
#  'произвел',
#  'диструктивные',
#  'получаешь',
#  'идешь',
#  'выбираешь',
#  'ассершне',
#  'прописаны',
#  'поискать',
#  'cloudtrai',
#  'живого',
#  'тыкать',
#  'состояний',
#  'зовется',
#  'lifecycle',
#  'trollface',
#  'сохраненными',
#  'запросами',
#  'разрешаем',
#  'наезда',
#  'неудаляющиеся',
#  'иниты',
#  'бута',
#  'передавай',
#  'марку',
#  'шаттлворуту',
#  'тёщи',
#  'апдейтится',
#  'небольшой',
#  'срачик',
#  'снимает',
#  'софт',
#  'белого',
#  'либ',
#  'юсервера',
#  'айпонвебовский',
#  'разламывают',
#  'перезалить',
#  'intended',
#  'physical',
#  'девопсам',
#  'делах',
#  'поясню',
#  'иксах',
#  'компах',
#  'makes',
#  'sense',
#  'звучит',
#  'удивительно',
#  'иксы',
#  'бессрочно',
#  'роботов',
#  'дохнет',
#  'скинь',
#  'ось',
#  'отрубается',
#  'строчка',
#  'greater',
#  'memory',
#  'driver',
#  'dhcp',
#  'flush',
#  'blocking',
#  'initialization',
#  'sequence',
#  'подмножество',
#  'сайтов',
#  'отключается',
#  'кононова',
#  'добавится',
#  'nwagner',
#  'предоставила',
#  'оказался',
#  'откроется',
#  'перепутал',
#  'подергали',
#  'присутствуют',
#  'каналах',
#  'публично',
#  'laugh',
#  'тогда',
#  'публичное',
#  'унижение',
#  'опубликована',
#  'присутствие',
#  'разная',
#  'опубликовался',
#  'обрати',
#  'четырёх',
#  'проставляется',
#  'подозрительным',
#  'заменены',
#  'плейсхолдеры',
#  'ver',
#  'контролфайлы',
#  'ради',
#  'гипотезы',
#  'заполнил',
#  'граблям',
#  'инита',
#  'питоновский',
#  'управляющие',
#  'поправит',
#  'контрол',
#  'уменьшит',
#  'энтропию',
#  'чуточку',
#  'приблизит',
#  'всеобщему',
#  'счастью',
#  'билдскрипт',
#  'подставляет',
#  'грязный',
#  'дефолтное',
#  'интересен',
#  'фрагмент',
#  'hardlinking',
#  'понятна',
#  'совпадало',
#  'берет',
#  'binary',
#  'фиктивным',
#  'отправителем',
#  'выдавал',
#  'коннекта',
#  'король',
#  'юзером',
#  'выясняй',
#  'защищает',
#  'apolev',
#  'приглашаю',
#  'роботам',
#  'аутлуковый',
#  'клал',
#  'входящего',
#  'сообщающий',
#  'получателю',
#  'автореспондить',
#  'особых',
#  'системами',
#  'системой',
#  'наваерное',
#  'акурат',
#  'примонстрячил',
#  'антенну',
#  'фонишь',
#  'тележка',
#  'безопасного',
#  'перевоза',
#  'техники',
#  'связан',
#  'упало',
#  'сверхновом',
#  'unreachable',
#  'обещали',
#  'вторник',
#  'вторников',
#  'управятся',
#  'меняют',
#  'разрулить',
#  'стажёры',
#  'простаивают',
#  'оборот',
#  'нанеслись',
#  'чуваки',
#  'правду',
#  'накажем',
#  'плохой',
#  'одноразово',
#  'политике',
#  'растолковать',
#  'испытатательный',
#  'workstation',
#  'сложных',
#  'обоснований',
#  'screensharing',
#  'программой',
#  'разрешенные',
#  'аналоги',
#  'усерверной',
#  'лождная',
#  'заставляют',
#  'похищал',
#  'собаку',
#  'угрожает',
#  'расправой',
#  'определенным',
#  'критериям',
#  'раскладка',
#  'en',
#  'ru',
#  'айпишниками',
#  'vadim',
#  'knyazev',
#  'define',
#  'фразы',
#  'общения',
#  'гуглом',
#  'синхронизация',
#  'зависят',
#  'примеру',
#  'перестарались',
#  'выпиливали',
#  'корректный',
#  'poland',
#  'tune',
#  'checker',
#  'smaller',
#  'возмёт',
#  'помнит',
#  'очередям',
#  'успешные',
#  'his',
#  'eric',
#  'hammond',
#  'taken',
#  'prompted',
#  'helping',
#  'requestor',
#  'diagnostic',
#  'икает',
#  'модуля',
#  'обозначьте',
#  'улицу',
#  'подышать',
#  'ужинать',
#  'высокая',
#  'степень',
#  'уверенности',
#  'восстановим',
#  'управление',
#  'sofia',
#  'впиливал',
#  'ntarasova',
#  'вернись',
#  'перенес',
#  'applied',
#  'successfully',
#  'читатели',
#  'лифтов',
#  'шестого',
#  'относящееся',
#  'инторнет',
#  'шатать',
#  'установите',
#  'возникло',
#  'недопонимание',
#  'bosnia',
#  'клава',
#  'ушатан',
#  'черезраз',
#  'беде',
#  'инфраструктурой',
#  'кратковременно',
#  'рушатся',
#  'зарезолвили',
#  'обидно',
#  'занимаетесь',
#  'питоне',
#  'библиотеки',
#  'лс',
#  'прогнались',
#  'сохранялся',
#  'container',
#  'холла',
#  'новий',
#  'нужон',
#  'узнавать',
#  'починю',
#  'впном',
#  'утреца',
#  'прикручивания',
#  'апаче',
#  'нжинкса',
#  'utopia',
#  'задолбал',
#  'периодами',
#  'передал',
#  'руководителю',
#  'максим',
#  'мейнтенанса',
#  'задаче',
#  'чините',
#  'конфигурировать',
#  'командыю',
#  'nkruglyak',
#  'неточно',
#  'засинканы',
#  'свежее',
#  'ойтишнеги',
#  'микрософт',
#  'телеке',
#  'принесли',
#  'теряли',
#  'подумал',
#  'неграмотные',
#  'вьетнамцы',
#  'хакнули',
#  'уведут',
#  'деньги',
#  'отправляют',
#  'рандомных',
#  'проверяют',
#  'бдительность',
#  'проявим',
#  'осторожность',
#  'гифка',
#  'пользования',
#  'дверцой',
#  'животных',
#  'жаль',
#  'специальные',
#  'аудиторы',
#  'отправляли',
#  'файликом',
#  'нейтральным',
#  'дергал',
#  'итогам',
#  'исследований',
#  'отчет',
#  'пикселей',
#  'заффилился',
#  'дернули',
#  'четырех',
#  'компаленс',
#  'virtual',
#  'purely',
#  'ньюкамера',
#  'научились',
#  'пуппет',
#  'ар',
#  'definition',
#  'виджетов',
#  'ademidyuk',
#  'ogrigorenko',
#  'повесьте',
#  'ольгу',
#  'приходили',
#  'тонких',
#  'проксимити',
#  'карт',
#  'стандартных',
#  'откатить',
#  'avtikhon',
#  'ebakulin',
#  'успеть',
#  'овнера',
#  'подблочивает',
#  'туман',
#  'войны',
#  'развеялся',
#  'соседи',
#  'инету',
#  'засучить',
#  'рукава',
#  'баш',
#  'бесшовно',
#  'переключались',
#  'хорошее',
#  'годное',
#  'провайдере',
#  'extranet',
#  'просят',
#  'галочки',
#  'платный',
#  'поставили',
#  'поставим',
#  'тэгу',
#  'mean',
#  'дебку',
#  'свежепоменяный',
#  'ножками',
#  'addon',
#  'принять',
#  'шорткаты',
#  'маленькие',
#  'выпадающие',
#  'esc',
#  'шорткатами',
#  'экране',
#  'короче',
#  'giving',
#  'дашбордах',
#  'открывалась',
#  'отдельная',
#  'привычке',
#  'закрываешь',
#  'посмотрев',
#  'теряешь',
#  'новшество',
#  'улучшили',
#  'эт',
#  'дуров',
#  'верни',
#  'стену',
#  'кастомном',
#  'макросе',
#  'пишем',
#  'превращал',
#  'css',
#  'класса',
#  'колесом',
#  'щёлкать',
#  'лкм',
#  'спорю',
#  'однопальцевое',
#  'сегодняшнем',
#  'ивановым',
#  'неразборчивый',
#  'нагибает',
#  'секретный',
#  'пыхтит',
#  'персональном',
#  'истекла',
#  'отркывалась',
#  'успел',
#  'даж',
#  'oke',
#  'входа',
#  'капчи',
#  'чистили',
#  'браузеры',
#  'пробовали',
#  'silly',
#  'nobody',
#  'физических',
#  'бц',
#  'николай',
#  'мартынов',
#  'уважуха',
#  'николаю',
#  'николая',
#  'jmx',
#  'кассандрах',
#  'попадал',
#  'перезду',
#  'предустановленной',
#  'виндой',
#  'follks',
#  'trouble',
#  'viewing',
#  'бекапяться',
#  'рабочии',
#  'полезная',
#  'техопсы',
#  'извинить',
#  'юслайсера',
#  'корпоративом',
#  'опсовый',
#  'тимбилдинг',
#  'угу',
#  'флуда',
#  'порезали',
#  'confluenceю',
#  'имен',
#  'лдапу',
#  'необходимых',
#  'настроенно',
#  'заведения',
#  'новго',
#  'усерверленд',
#  'шагам',
#  'расписано',
#  'ошибится',
#  'назначили',
#  'окейси',
#  'верификации',
#  'маркировалось',
#  'помнить',
#  'запретили',
#  'запретил',
#  'неизвестного',
#  'authenticator',
#  'удобные',
#  'надежные',
#  'ошибаться',
#  'ошибаюсь',
#  'большому',
#  'номеру',
#  'работаете',
#  'ashot',
#  'заббих',
#  'мейтенанас',
#  'че',
#  'поотвалиавлись',
#  'суперновой',
#  'genesis',
#  'супернове',
#  'переключились',
#  'переключили',
#  'магистрального',
#  'исключение',
#  'сноски',
#  'всплывающие',
#  'наведению',
#  'убираем',
#  'разделение',
#  'сообщаем',
#  'сообщил',
#  'диапазон',
#  'конфлюэнца',
#  'приказал',
#  'promote',
#  'criticality',
#  'per',
#  'минутный',
#  'поломалось',
#  'цветной',
#  'узким',
#  'кругом',
#  'обвиняют',
#  'поборник',
#  'надоело',
#  'виноватым',
#  'плюется',
#  'потухнет',
#  'погаснет',
#  'spreadsheets',
#  'драйва',
#  'откроешь',
#  'recommended',
#  'полечить',
#  'повторый',
#  'ввод',
#  'интерактивной',
#  'grant',
#  'davies',
#  'переходить',
#  'цветного',
#  'лепестков',
#  'smikhailov',
#  'malaysia',
#  'подцепиться',
#  'введения',
#  'рабчих',
#  'станций',
#  'поменялись',
#  'guam',
#  'помнишь',
#  'country',
#  'включённом',
#  'функция',
#  'незнающему',
#  'догадаться',
#  'репутации',
#  'долгого',
#  'лока',
#  'восстанавливается',
#  'сбоев',
#  'раздел',
#  'переполнился',
#  'предпринять',
#  'fdutils',
#  'newly',
#  'database',
#  'directories',
#  'extracted',
#  'apport',
#  'written',
#  'indicates',
#  'subprocess',
#  'paste',
#  'killed',
#  'signal',
#  'сбилдились',
#  'недоехали',
#  'интергации',
#  'jenk',
#  'детально',
#  'плю',
#  'дополнительно',
#  'единицы',
#  'посмортем',
#  'пичаль',
#  'постараемся',
#  'приклaдывается',
#  'прилегли',
#  'биида',
#  'кассандра',
#  'прилегла',
#  'summary',
#  'wanted',
#  'nodes',
#  'roughly',
#  'resulted',
#  'cluster',
#  'startup',
#  'граблю',
#  'наступать',
#  'обертка',
#  'гитхабовым',
#  'проверенным',
#  'grinning',
#  'оканчивается',
#  'командой',
#  'относящихся',
#  'списанных',
#  'продажу',
#  'шнуру',
#  'лучше',
#  'lte',
#  'smile',
#  'ребутнем',
#  'аттрибутов',
#  'служебного',
#  'крутить',
#  'графики',
#  'регулярного',
#  'ввода',
#  'фактора',
#  'anguilla',
#  'торопился',
#  'joshua',
#  'solomon',
#  'привету',
#  'vatikan',
#  'сап',
#  'заказывал',
#  'шнур',
#  'давали',
#  'интернетная',
#  'готова',
#  'опенвн',
#  'сислогу',
#  'достоверности',
#  'увольняюсь',
#  'техникой',
#  'bswlua',
#  'кинуло',
#  'химичит',
#  'корпоративыные',
#  'серебристые',
#  'черные',
#  'человеческая',
#  'ian',
#  'stalvies',
#  'ux',
#  'звонит',
#  'частичные',
#  'зарубежный',
#  'бесконечное',
#  'hops',
#  'byte',
#  'сторооне',
#  'мысль',
#  'подумав',
#  'отвергаю',
#  'отпал',
#  'админит',
#  'заколебался',
#  'автоматизация',
#  'сломанную',
#  'переведём',
#  'обновились',
#  'добавилось',
#  'вешается',
#  'инбоксе',
#  'пролетали',
#  'never',
#  'конкретную',
#  'нажми',
#  'зайди',
#  'снесет',
#  'разбираюсь',
#  'труба',
#  'руки',
#  'вкатал',
#  'упавший',
#  'sabotage',
#  'hankey',
#  'тегать',
#  'нельзя',
#  'трогать',
#  'проблемный',
#  'описании',
#  'указана',
#  'правьте',
#  'научитесь',
#  'прямым',
#  'финансовым',
#  'потерям',
#  'сэкономит',
#  'личное',
#  'подобная',
#  'aluminium',
#  'сняли',
#  'таймшитив',
#  'написывает',
#  'используй',
#  'фильтре',
#  'помечается',
#  'лейблом',
#  'фикс',
#  'даются',
#  'следуют',
#  'поколения',
#  'гуглогрупп',
#  'коннектами',
#  'имейдж',
#  'тестовыми',
#  'бакетами',
#  'теоретическая',
#  'messagebox',
#  'айпонвеб',
#  'нормалбнол',
#  'машинам',
#  'complained',
#  'ends',
#  'гуглогруппы',
#  'suddenly',
#  'смыслу',
#  'аналогия',
#  ...]

# %%
CONTEXT_SIZE = 2
EMBEDDING_DIM = 50

trigrams = [([TOKENS[i], TOKENS[i + 1]], TOKENS[i + 2])
            for i in range(len(TOKENS) - 2)]

vocab = set(TOKENS)
word_to_ix = {word: i for i, word in enumerate(vocab)}


class NGramLanguageModeler(nn.Module):

    def __init__(self, vocab_size, embedding_dim, context_size):
        super(NGramLanguageModeler, self).__init__()
        self.embeddings = nn.Embedding(vocab_size, embedding_dim)
        self.linear1 = nn.Linear(context_size * embedding_dim, 128)
        self.linear2 = nn.Linear(128, vocab_size)

    def forward(self, inputs):
        embeds = self.embeddings(inputs).view((1, -1))
        out = F.relu(self.linear1(embeds))
        out = self.linear2(out)
        log_probs = F.log_softmax(out, dim=1)
        return log_probs


losses = []
loss_function = nn.NLLLoss()
model = NGramLanguageModeler(len(vocab), EMBEDDING_DIM, CONTEXT_SIZE)
optimizer = optim.SGD(model.parameters(), lr=0.001)

for epoch in range(10):
    total_loss = 0
    for context, target in trigrams:

        # Step 1. Prepare the inputs to be passed to the model (i.e, turn the words
        # into integer indices and wrap them in tensors)
        context_idxs = torch.tensor([word_to_ix[w] for w in context], dtype=torch.long)

        # Step 2. Recall that torch *accumulates* gradients. Before passing in a
        # new instance, you need to zero out the gradients from the old
        # instance
        model.zero_grad()

        # Step 3. Run the forward pass, getting log probabilities over next
        # words
        log_probs = model(context_idxs)

        # Step 4. Compute your loss function. (Again, Torch wants the target
        # word wrapped in a tensor)
        loss = loss_function(log_probs, torch.tensor([word_to_ix[target]], dtype=torch.long))

        # Step 5. Do the backward pass and update the gradient
        loss.backward()
        optimizer.step()

        # Get the Python number from a 1-element Tensor by calling tensor.item()
        total_loss += loss.item()
    losses.append(total_loss)
print(losses)  # The loss decreased every iteration over the training data!
# Out:
# /home/artkra/.cache/pypoetry/virtualenvs/faqer-EGfSzUrq-py3.6/lib/python3.6/site-packages/torch/autograd/__init__.py:132: UserWarning: CUDA initialization: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx (Triggered internally at  /pytorch/c10/cuda/CUDAFunctions.cpp:100.)
#   allow_unreachable=True)  # allow_unreachable flag
# [527.2016248703003, 523.2607398033142, 519.3562743663788, 515.4896667003632, 511.6469314098358, 507.832147359848, 504.0425100326538, 500.2685475349426, 496.50909209251404, 492.75991773605347, 489.0201470851898, 485.2982292175293, 481.58196234703064, 477.86278319358826, 474.1433870792389, 470.42631673812866, 466.7085223197937, 462.9877142906189, 459.2546639442444, 455.5132393836975, 451.7613067626953, 447.9998435974121, 444.21028566360474, 440.4048275947571, 436.573077917099, 432.7195255756378, 428.84029936790466, 424.9308590888977, 421.0001564025879, 417.036114692688, 413.04188323020935, 409.0145614147186, 404.9681316614151, 400.87253189086914, 396.7545608282089, 392.6032922267914, 388.423636674881, 384.2065261602402, 379.9643783569336, 375.6837738752365, 371.3680419921875, 367.0347810983658, 362.6610035896301, 358.2613434791565, 353.8260135650635, 349.3560050725937, 344.8538933992386, 340.31707775592804, 335.7516059279442, 331.15143620967865]

# %%
nn.PairwiseDistance()(model.embeddings(torch.tensor([word_to_ix['beauty']], dtype=torch.long)),
model.embeddings(torch.tensor([word_to_ix['blood']], dtype=torch.long)))
# Out:
# tensor([11.0422], grad_fn=<NormBackward1>)
